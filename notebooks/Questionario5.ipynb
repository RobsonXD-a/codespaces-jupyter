# %%
#Nome: Henrique Teixeira Duarte
#RA: 11202321531

# %%
import pandas as pd
#df = pd.read_csv("https://drive.google.com/u/1/uc?id=182_Z-bL7n9itkupECYhIOEGuIjfQbF0Z&export=download")

# %%
# %matplotlib inline
df=pd.read_csv("https://drive.google.com/u/3/uc?id=1rUD-bB5awMtsfBixEcvYAbuwA6pR9C7w&export=download", sep=';', decimal=',')
df.hist(column='Temperatura', bins=9)
# Out:
# array([[<Axes: title={'center': 'Temperatura'}>]], dtype=object)

# %%
import pandas as pd
df = pd.read_csv("https://drive.google.com/u/3/uc?id=1pPp_149L-KAbQvojKmZDlG78xHphjKeE&export=download", sep=";", decimal=",")
df["Fahrenheit"]= df["Temperatura"]*(9/5)+32
df.boxplot("Fahrenheit")
# Out:
# <Axes: >

# %%
import numpy as np 
import pandas as pd

df = pd.read_csv("https://drive.google.com/u/3/uc?id=1w0cEAwCkAKPWAPIEJgcsZwVWzzbtnVvY&export=download", sep=";", decimal=",")
df.query('Região == "Asia"', inplace=True)
print(df['Fertilidade'].mean())
print(np.percentile(df["Fertilidade"],q=25))
# Out:
# 3.65
# 3.0
